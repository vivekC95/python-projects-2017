# %%
import folium

# %%
m = folium.Map(location = [45.5236, -122.6750])

# %%
folium.TileLayer(tiles='cartodbdark_matter').add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker(location=[45.5244, -122.6699],popup = "This Marker", icon=folium.Icon(color = 'red',icon='info-sign')).add_to(m)

# %%
m.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Circle(location=[45.4881,-122.8889],radius=30,popup='Aloha',color='blue').add_to(m)
folium.Circle(location=[45.4698,-122.4989],radius=30,popup='Aloha',color='red').add_to(m)
folium.Circle(location=[45.6716,-122.5058],radius=30,popup='Aloha',color='red').add_to(m)
folium.Circle(location=[45.5275,-122.3863],radius=30,popup='Aloha',color='blue').add_to(m)
folium.Circle(location=[45.6044,-122.1375],radius=30,popup='Aloha',color='yellow').add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.CircleMarker(location =[45.6001,-122.8183],radius = 30,popup='Place 1' ).add_to(m)

# %%
m.save('another.html')
